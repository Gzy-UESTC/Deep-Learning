# %% [markdown]
# # Implementation

# %% [markdown]
# ## 数据集
#
# 验证数据集：
# 评估模型好坏，不要和训练数据混在一起
#
# 测试数据集：只用一次的数据集
#
# K-折交叉验证：
# 没有足够多数据时使用

# %% [markdown]
# ## 过拟合和欠拟合
# 根据数据集的简单复杂选择对应的模型容量
#
# 模型容量是拟合各种函数的能力
#
# ![image.png](attachment:image.png)
