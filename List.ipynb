# %% [markdown]
# | 学习阶段 | 核心模块 | 学习重点 (核心技术栈) |
# | :--- | :--- | :--- |
# | **阶段一** | **现代 C++** | C++11/14/17 特性、指针与引用、RAII (智能指针)、多线程 (`std::thread`, `std::mutex`)、模板元编程。 |
# | | **Python 进阶** | 面向对象、装饰器、多进程/多线程与 GIL 机制、`numpy` 熟练应用。 |
# | | **计算机系统与 OS** | 内存层次 (L1/L2/L3/主存)、缓存一致性、虚拟内存与分页、进程/线程调度、I/O 模型。 |
# | **阶段二** | **PyTorch 底层机制** | Tensor 内存连续排布 (Stride, Contiguous)、Autograd 自动求导计算图、`_pytree` 工具。 |
# | | **Transformer 解构** | Attention 数学推导、矩阵乘法 (GEMM) 拆解、KV Cache (键值缓存) 数据结构。 |
# | **阶段三** | **CUDA 编程** | GPU 硬件架构 (SM/Warp/Tensor Core)、编程模型 (Grid/Block/Thread)、内存合并访问、Shared Memory、Warp 同步。 |
# | | **OpenAI Triton** | Triton 语法与编译逻辑、块级 (Block-level) 内存操作与计算。 |
# | **阶段四** | **集合通信原理** | MPI/NCCL 核心原语：Broadcast, Reduce, All-Reduce, All-Gather, Reduce-Scatter、Ring/Tree 拓扑。 |
# | | **分布式训练 (Training)** | DP / DDP (数据并行)、TP (张量并行)、PP (流水线并行)、ZeRO 显存优化 (DeepSpeed)。 |
# | | **推理加速 (Inference)** | 连续批处理 (Continuous Batching)、PagedAttention (显存分页)、模型量化 (AWQ/GPTQ/INT4)、投机解码。 |
# | **阶段五** | **Training 源码剖析** | **Megatron-LM** (NVIDIA 标杆)、**DeepSpeed** (微软)。 |
# | | **Inference 源码剖析** | **vLLM** (PagedAttention 发源地)、**TensorRT-LLM**。 |
