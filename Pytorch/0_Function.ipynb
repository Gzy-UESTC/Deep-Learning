# %% [markdown]
# # 实用函数

# %%
import torch

torch.cuda.is_available()

dir(torch) # 列出torch模块的所有属性和方法

dir(torch.cuda.is_available) # 列出torch.cuda.is_available函数的所有属性和方法

help.torch.cuda.is_available # 查看torch.cuda.is_available函数的帮助文档
